# %% [markdown]
# <a href="https://colab.research.google.com/github/Clalloures/TRABALHO-PUC/blob/main/ComandosLinux_Wind.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 2
#
#
# Aula comparando comandos Linux e Windows:

# %% [markdown]
# ## Comandos básicos

# %% [markdown]
# Comparação de comandos Linux e Windows:
#
#
#
# *   dir - ls
# *   cd - pwd
# *   cd [dict] : mesmo funcionamento
# *   cls - clear

# %% [markdown]
# ### Comando DIR

# %% [markdown]
# Comando para verificar os execuráveis:
#
# ```
# dir *.exe
# ```
#
#
#
# Comando para verificar os execuráveis do ambiente aos poucos:
#
#
#
# ```
# dir *.exe /w/p
# ```
#
# ![b.PNG](data:image/png;base64,...)
#
#
# Comando para verificar todos os executáveis que começam com f em uma lista mais fácil de visualizar:
#
# ```
# dir f*.exe
# ```
#
# ![a.PNG](data:image/png;base64,...)

# %% [markdown]
# ### Comando CD

# %% [markdown]
# Usando o cd igual usamos no Linux:
#
# ```
# cd [local]
# ```
#
# Caso queiramos entrar no diretório origem, apenas fazemos o comando
#
# ```
# cd \
# ```
#
# Podemos usar o *tab* para que ele nos ajude a achar o ambiente desejado, após colocar a primeira letra ele irá ir complentando com as opções possíveis:
#
# para voltar 2 pastas:
#
# ![h.PNG](data:image/png;base64,...)

# %% [markdown]
# ### Comando de criação

# %% [markdown]
# ```
# md
# ```
#
# ```
# mkdir
# ```
#
# ![c.PNG](data:image/png;base64,...)

# %% [markdown]
# remover arquivo \ pasta:
#
#
#
# ```
# rmdir <Nome>
# ```
# ![d.PNG](data:image/png;base64,...)

# %% [markdown]
# ### Comando tree

# %% [markdown]
# O comando tree mostra os caminhos possíveis a partir do local atual
#
#
#
# ```
# tree
# ```
# ![e.PNG](data:image/png;base64,...)

# %% [markdown]
# Na nossa pasta da aula, vamos add duas pastas internas e depois mostrar o tree
#
# ![f.PNG](data:image/png;base64,...)

# %% [markdown]
# ### Comando ren

# %% [markdown]
# Comando para alterar o nome
#
#
#
# ```
# ren [nome atual] [novo nome]
# ```

# %% [markdown]
# ### Comando para copiar:

# %% [markdown]
# ```
# copy c:\Windows\System32\w*.exe .
# ```
#
# ```
# copy c:\Windows\System32\w*.exe
# ```
#
# ```
# copy c:\Windows\System32\w*.exe [novo local]
# ```

# %% [markdown]
# ### Comando Type

# %% [markdown]
# ```
# type <file>
# ```
#
#
# você pode combinar com o comando more para poder ir vendo os valores aos poucos
#
# ![g.PNG](data:image/png;base64,...)

# %% [markdown]
# Podemos usar more conectado com outros comandos também:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Mais avançados

# %% [markdown]
# ## Redirecionar para um arquivo

# %% [markdown]
# ![i.PNG](data:image/png;base64,...)
#
#
#
# ![j.PNG](data:image/png;base64,...)

# %% [markdown]
# Podemos criar outros tipos de arquivos també, como por exemplo este que iremos colocar informações de comandos relacionados com o dir:

# %% [markdown]
# ![l.PNG](data:image/png;base64,...)![k.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Comparação de tipos de arquivos
#
#
#
# * Binários:
# 1.  Executável (.exe) - linguagem de máquina
# 2.  Texto (.txt, .c, .java, .py) - Codificados em ASCII
# 3.  Outros (pdf, doc, xls, jpg, gif)

# %% [markdown]
# ## Comandos:

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !dir
# Out:
# drive  sample_data
